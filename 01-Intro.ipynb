# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.20.3'

# %% [markdown]
# ## Question 1

# %%
data = pd.read_csv("data.csv")

# %% [markdown]
# ## Question 2

# %%
data.shape
# Out:
# (11914, 16)

# %% [markdown]
# there are 11,914 records

# %% [markdown]
# ## Question 3

# %%
data['Make'].value_counts()[:3]
# Out:
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Name: Make, dtype: int64

# %% [markdown]
# the answer is Chevrolet, Ford and Volkswagen

# %% [markdown]
# ## Question 4

# %%
audis = data[data.Make == 'Audi']

# %%
audis.Model.nunique()
# Out:
# 34

# %% [markdown]
# the answer is that there are 34 audi models in the dataset

# %% [markdown]
# ## Question 5

# %%
nonulls = data.isnull().sum()

# %%
nonulls[nonulls != 0].shape
# Out:
# (5,)

# %% [markdown]
# the answer is 5

# %% [markdown]
# ## Question 6

# %%
# 1
median_ec = data['Engine Cylinders'].median()
mec
# Out:
# 6.0

# %%
# 2
mode_ec = data['Engine Cylinders'].mode()
mode_ec
# Out:
# 0    4.0
# dtype: float64

# %%
# 3
data["Engine Cylinders"].isnull().sum()
# Out:
# 30

# %%
data["Engine Cylinders"].fillna(4.0, inplace=True)

# %%
data["Engine Cylinders"].isnull().sum()
# Out:
# 0

# %%
data['Engine Cylinders'].median()
# Out:
# 6.0

# %% [markdown]
# so the median was the same even after filling the missing values with the most frequent value

# %% [markdown]
# ## Question 7

# %%
lotus = data[data.Make == 'Lotus']

# %%
lotus
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
lotus = lotus[["Engine HP", "Engine Cylinders"]]
lotus
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
lotus = lotus.drop_duplicates()
lotus
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
lotus
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
X = lotus.values

# %%
X
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
XTX = np.dot(X.T, X)

# %%
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
y = [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800]

# %%
temp = np.dot(XTX_inv, X.T)

# %%
w = np.dot(temp, y)

# %%
w
# Out:
# array([  4.59494481, -63.56432501])

# %% [markdown]
# the anser is 4.5949

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')
